# %%
import h5py
import numpy as np
import sys
sys.path.insert(0,"../DeepMIMO/")

# %%
f1 = h5py.File("../DeepMIMO/DeepMIMO Dataset/DeepMIMO_dataset_I_2p4_64_ofdm.mat",'r')

# %%
user_indices = range(0,1000)
for user_index in user_indices:
    print(user_index)
    for bs_index in [0,1,2,3]:
        print(list(map(float,f1[f1[f1['DeepMIMO_dataset'][bs_index][0]]['user'][user_index][0]]['loc'])))
# Out:
# 0
# [-21.9427, 12.4355, 1.0]
# [-21.9427, 12.4355, 1.0]
# [-21.9427, 12.4355, 1.0]
# [-21.9427, 12.4355, 1.0]
# 1
# [-21.9327, 12.4355, 1.0]
# [-21.9327, 12.4355, 1.0]
# [-21.9327, 12.4355, 1.0]
# [-21.9327, 12.4355, 1.0]
# 2
# [-21.9227, 12.4355, 1.0]
# [-21.9227, 12.4355, 1.0]
# [-21.9227, 12.4355, 1.0]
# [-21.9227, 12.4355, 1.0]
# 3
# [-21.9127, 12.4355, 1.0]
# [-21.9127, 12.4355, 1.0]
# [-21.9127, 12.4355, 1.0]
# [-21.9127, 12.4355, 1.0]
# 4
# [-21.9027, 12.4355, 1.0]
# [-21.9027, 12.4355, 1.0]
# [-21.9027, 12.4355, 1.0]
# [-21.9027, 12.4355, 1.0]
# 5
# [-21.8927, 12.4355, 1.0]
# [-21.8927, 12.4355, 1.0]
# [-21.8927, 12.4355, 1.0]
# [-21.8927, 12.4355, 1.0]
# 6
# [-21.8827, 12.4355, 1.0]
# [-21.8827, 12.4355, 1.0]
# [-21.8827, 12.4355, 1.0]
# [-21.8827, 12.4355, 1.0]
# 7
# [-21.8727, 12.4355, 1.0]
# [-21.8727, 12.4355, 1.0]
# [-21.8727, 12.4355, 1.0]
# [-21.8727, 12.4355, 1.0]
# 8
# [-21.8627, 12.4355, 1.0]
# [-21.8627, 12.4355, 1.0]
# [-21.8627, 12.4355, 1.0]
# ...

# %%
x = f1[f1[f1['DeepMIMO_dataset'][0][0]]['user'][41238][0]]['loc']
list(x)

# %%
x = f1[f1[f1['DeepMIMO_dataset'][1][0]]['user'][41238][0]]['loc']
list(x)

# %%
f2 = h5py.File("../DeepMIMO Dataset/DeepMIMO_dataset_I_2p5_64_ofdm.mat",'r')

# %%
y = f2[f2[f2['DeepMIMO_dataset'][0][0]]['user'][2][0]]['loc']
y[0],y[1],y[2]
